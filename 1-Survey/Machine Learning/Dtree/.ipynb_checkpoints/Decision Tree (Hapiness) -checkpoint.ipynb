# %% [markdown]
# # Decision Tree (Hapiness)

# %% [markdown]
# Use Decision Tree approach to analyze employee hapiness. I use happy or unhappy as label in this attempt. Happy person will be the upper 66.67th percentile, while unhappy person will be bottom 33.33th percentile.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
rawdata = pd.read_excel("../Data/dEX Team Survey.xlsx")

# %%
rawdata.head()
# Out:
#    ID          Start time     Completion time      Email  Name  \
# 0   1 2019-06-05 15:17:38 2019-06-05 15:20:47  anonymous   NaN
# 1   2 2019-06-05 15:22:08 2019-06-05 15:24:30  anonymous   NaN
# 2   3 2019-06-05 15:26:55 2019-06-05 15:30:23  anonymous   NaN
# 3   4 2019-06-05 15:40:57 2019-06-05 15:44:18  anonymous   NaN
# 4   5 2019-06-05 15:03:34 2019-06-05 15:55:58  anonymous   NaN
#
#    How happy are you at work?  \
# 0                           8
# 1                           7
# 2                           7
# 3                           3
# 4                           4
#
#    How likely are you to recommend your friend or colleague to work here?  \
# 0                                                  5
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  0
#
#    Do you feel you are driving value for GC?  \
# ...

# %% [markdown]
# ### Data Wrangling

# %%
data = rawdata.drop(["ID","Start time", "Completion time", "Email","Name",'Are you fully empowered and accountable for the work that you do?','Hypothetically, if you were to quit tomorrow, what would your reason be? (Please select one)','Total Score'], axis=1)

# %%
data.head()
# Out:
#    How happy are you at work?  \
# 0                           8
# 1                           7
# 2                           7
# 3                           3
# 4                           4
#
#    How likely are you to recommend your friend or colleague to work here?  \
# 0                                                  5
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  0
#
#    Do you feel you are driving value for GC?  \
# 0                                          7
# 1                                          7
# 2                                          8
# 3                                          5
# 4                                          2
#
#    Do you feel like dEX team members give each other respect?  \
# 0                                                  9
# ...

# %%
data['How happy are you at work?'].describe()
# Out:
# count    22.000000
# mean      6.409091
# std       2.085302
# min       2.000000
# 25%       5.250000
# 50%       7.000000
# 75%       8.000000
# max       9.000000
# Name: How happy are you at work?, dtype: float64

# %%
#Finding percentile
p = np.percentile(data['How happy are you at work?'], 100/3) 
print(p)
# Out:
# 6.000000000000001

# %%
#Create label
data['Happy or Not'] = data['How happy are you at work?']>6.01

# %%
data.head()
# Out:
#    How happy are you at work?  \
# 0                           8
# 1                           7
# 2                           7
# 3                           3
# 4                           4
#
#    How likely are you to recommend your friend or colleague to work here?  \
# 0                                                  5
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  0
#
#    Do you feel you are driving value for GC?  \
# 0                                          7
# 1                                          7
# 2                                          8
# 3                                          5
# 4                                          2
#
#    Do you feel like dEX team members give each other respect?  \
# 0                                                  9
# ...

# %% [markdown]
# ### Machine Learning

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('Happy or Not',axis=1)
y = data['Happy or Not']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[2 1]
#  [2 3]]
#
#
#               precision    recall  f1-score   support
#
#        False       0.50      0.67      0.57         3
#         True       0.75      0.60      0.67         5
#
#     accuracy                           0.62         8
#    macro avg       0.62      0.63      0.62         8
# weighted avg       0.66      0.62      0.63         8

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=15)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=15,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
print('\n')
print(classification_report(y_test,rfc_pred))
# Out:
# [[0 3]
#  [0 5]]
#
#
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00         3
#         True       0.62      1.00      0.77         5
#
#     accuracy                           0.62         8
#    macro avg       0.31      0.50      0.38         8
# weighted avg       0.39      0.62      0.48         8
# c:\python\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot
# Out:
# c:\python\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
features = list(data.columns[1:-1])
print(len(features))
classname = ['UnHappy','Happy']
#features
# Out:
# 12

# %%
dot_data = StringIO()  
XX = data.drop(['How happy are you at work?','Happy or Not'],axis=1)
yy = data['Happy or Not']


dtree1 = DecisionTreeClassifier()
dtree1.fit(XX,yy)

export_graphviz(dtree1,class_names=classname, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())
