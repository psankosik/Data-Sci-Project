# %% [markdown]
# # Decision Tree (GC Value)

# %% [markdown]
# Use Decision Tree approach to analyze data. I use GC value as label in this attempt. Value driven will be the upper 67th percentile, while not driven will be bottom 33th percentile.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
rawdata = pd.read_excel("../Data/dEX Team Survey.xlsx")

# %%
rawdata.head()
# Out:
#    ID          Start time     Completion time      Email  Name  \
# 0   1 2019-06-05 15:17:38 2019-06-05 15:20:47  anonymous   NaN
# 1   2 2019-06-05 15:22:08 2019-06-05 15:24:30  anonymous   NaN
# 2   3 2019-06-05 15:26:55 2019-06-05 15:30:23  anonymous   NaN
# 3   4 2019-06-05 15:40:57 2019-06-05 15:44:18  anonymous   NaN
# 4   5 2019-06-05 15:03:34 2019-06-05 15:55:58  anonymous   NaN
#
#    How happy are you at work?  \
# 0                           8
# 1                           7
# 2                           7
# 3                           3
# 4                           4
#
#    How likely are you to recommend your friend or colleague to work here?  \
# 0                                                  5
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  0
#
#    Do you feel you are driving value for GC?  \
# ...

# %% [markdown]
# ### Data Wrangling

# %%
data = rawdata.drop(["ID","Start time", "Completion time", "Email","Name",'Are you fully empowered and accountable for the work that you do?','Hypothetically, if you were to quit tomorrow, what would your reason be? (Please select one)'], axis=1)

# %%
data.head()
# Out:
#    How happy are you at work?  \
# 0                           8
# 1                           7
# 2                           7
# 3                           3
# 4                           4
#
#    How likely are you to recommend your friend or colleague to work here?  \
# 0                                                  5
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  0
#
#    Do you feel you are driving value for GC?  \
# 0                                          7
# 1                                          7
# 2                                          8
# 3                                          5
# 4                                          2
#
#    Do you feel like dEX team members give each other respect?  \
# 0                                                  9
# ...

# %%
data['Do you feel you are driving value for GC?'].describe()
# Out:
# count    22.000000
# mean      7.090909
# std       1.743262
# min       2.000000
# 25%       6.250000
# 50%       7.000000
# 75%       8.000000
# max      10.000000
# Name: Do you feel you are driving value for GC?, dtype: float64

# %%
p = np.percentile(data['Do you feel you are driving value for GC?'], 100/3) 
print(p)
# Out:
# 7.0

# %%
data['Happy or Not'] = data['Do you feel you are driving value for GC?']>7

# %%
data.head()
# Out:
#    How happy are you at work?  \
# 0                           8
# 1                           7
# 2                           7
# 3                           3
# 4                           4
#
#    How likely are you to recommend your friend or colleague to work here?  \
# 0                                                  5
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  0
#
#    Do you feel you are driving value for GC?  \
# 0                                          7
# 1                                          7
# 2                                          8
# 3                                          5
# 4                                          2
#
#    Do you feel like dEX team members give each other respect?  \
# 0                                                  9
# ...

# %% [markdown]
# ### Machine Learning

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('Happy or Not',axis=1)
y = data['Happy or Not']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[5 0]
#  [0 3]]
#
#
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00         5
#         True       1.00      1.00      1.00         3
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=15)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=15,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
print('\n')
print(classification_report(y_test,rfc_pred))
# Out:
# [[5 0]
#  [0 3]]
#
#
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00         5
#         True       1.00      1.00      1.00         3
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot
# Out:
# c:\python\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
features = list(data.drop(['Do you feel you are driving value for GC?','Total Score','Happy or Not'],axis=1).columns[:])
print(len(features))
features
classname = ['Driven','Not Driven']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e494a3fdd2d6> in <module>
# ----> 1 features = list(data.drop(['Do you feel you are driving value for GC?','Total Score','Happy or Not'],axis=1).columns[:])
#       2 print(len(features))
#       3 features
#       4 classname = ['Driven','Not Driven']
#
# NameError: name 'data' is not defined

# %%
dot_data = StringIO()  
XX = data.drop(['Do you feel you are driving value for GC?','Happy or Not','Total Score'],axis=1)
yy = data['Happy or Not']


dtree1 = DecisionTreeClassifier()
dtree1.fit(XX,yy)

export_graphviz(dtree1,class_names=classname,out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())
