# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("F1101-22-2 (G11G) LR.CSV")

# %%
df.head()
# Out:
#             ="ID"           Name            Sent Time  UT measurement (mm)  \
# 0  ="- -11XI006B"  ="F1101-22-2"  2016-07-05 05:56:47               12.133
# 1  ="- -11XI006B"  ="F1101-22-2"  2016-07-05 18:06:49               12.138
# 2  ="- -11XI006B"  ="F1101-22-2"  2016-07-06 06:15:41               12.137
# 3  ="- -11XI006B"  ="F1101-22-2"  2016-07-06 18:28:35               12.135
# 4  ="- -11XI006B"  ="F1101-22-2"  2016-07-07 06:39:35               12.135
#
#    Temperature (°C)  PSI  Apply Temperature Compensation Flag
# 0            390.38  NaN                                    1
# 1            394.69  NaN                                    1
# 2            395.49  NaN                                    1
# 3            393.93  NaN                                    1
# 4            395.44  NaN                                    1

# %%
df.drop(['="ID"','Name','Apply Temperature Compensation Flag'],axis=1,inplace=True)

# %%
df.head()
# Out:
#              Sent Time  UT measurement (mm)  Temperature (°C)  PSI
# 0  2016-07-05 05:56:47               12.133            390.38  NaN
# 1  2016-07-05 18:06:49               12.138            394.69  NaN
# 2  2016-07-06 06:15:41               12.137            395.49  NaN
# 3  2016-07-06 18:28:35               12.135            393.93  NaN
# 4  2016-07-07 06:39:35               12.135            395.44  NaN

# %%
sns.pairplot(df[['UT measurement (mm)','Temperature (°C)']])

# %%
df['UT measurement (mm)'].plot(figsize=(20,5))

# %%
df['Temperature (°C)'].plot(figsize=(20,5));
