# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df1 = pd.read_csv('F1101-22-2 (G11G) LR.CSV')

# %%
df2 = pd.read_csv("P100254-1 (G43L) CDU-HGO.CSV")

# %%
df3 = pd.read_csv("P100254-2 (G4CY) CDU-HGO.CSV")

# %%
df1['UT measurement (mm)'].plot(figsize=(20,5));

# %%
df2['UT measurement (mm)'].plot(figsize=(20,5));

# %%
df3['UT measurement (mm)'].plot(figsize=(20,5));

# %%
df1['Temperature (°C)'].plot(figsize=(20,5));

# %%
df2['Temperature (°C)'].plot(figsize=(20,5));

# %%
df3['Temperature (°C)'].plot(figsize=(20,5));
